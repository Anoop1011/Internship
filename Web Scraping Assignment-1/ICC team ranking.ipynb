# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
PAGE = requests.get('https://www.icc-cricket.com/rankings/mens/rankings-predictor/odi')
PAGE
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(PAGE.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI | Rankings Predictor | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official ICC Cricket website - live matches, scores, news, highlights, commentary, rankings, videos and fixtures from the International Cricket Council." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI | Rankings Predictor | ICC" property="og:title"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" property="og:image"/>
# ...

# %%
Team_Name = []
for i in soup.find_all('td',class_="table-body__cell nationality-logo"):
    Team_Name.append(i.text)
Team_Name
# Out:
# []

# %%
Matches = []
for i in soup.find_all('td', class_="rankings-block__banner--matches"):
    Matches.append(i.text)
Matches
# Out:
# ['12']

# %%
Matche = soup.find('td', class_="table-body__cell u-center-text")
Matche.text
# Out:
# '22'

# %%
Matches = []
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    Matches.append((i.text))
Matches
# Out:
# ['22',
#  '2,756',
#  '19',
#  '2,005',
#  '22',
#  '2,304',
#  '23',
#  '2,325',
#  '19',
#  '1,872',
#  '24',
#  '2,275',
#  '29',
#  '2,658',
#  '32',
#  '2,306',
#  '18',
#  '1,238',
#  '20',
#  '1,083',
#  '18',
#  '814',
#  '19',
#  '724',
#  '18',
#  '603',
#  '17',
#  '539',
#  '30',
#  '919',
#  '20',
#  '544',
#  '11',
#  '246',
#  '18',
#  '298',
#  '22',
#  '134']

# %%
points = []
for i in soup.find_all('td', class_="rankings-block__banner--points"):
    points.append((i.text))
points
# Out:
# ['1,505']

# %%
points = []
for i in soup.find_all('td',class_="table-body__cell u-center-text"):
    points.append((i.text))
points
# Out:
# ['22',
#  '2,756',
#  '19',
#  '2,005',
#  '22',
#  '2,304',
#  '23',
#  '2,325',
#  '19',
#  '1,872',
#  '24',
#  '2,275',
#  '29',
#  '2,658',
#  '32',
#  '2,306',
#  '18',
#  '1,238',
#  '20',
#  '1,083',
#  '18',
#  '814',
#  '19',
#  '724',
#  '18',
#  '603',
#  '17',
#  '539',
#  '30',
#  '919',
#  '20',
#  '544',
#  '11',
#  '246',
#  '18',
#  '298',
#  '22',
#  '134']

# %%
Ratings = []
for i in soup.find_all('td',class_="rankings-block__banner--rating u-text-right"):
    Ratings.append((i.text))
Ratings
# Out:
# ['\n                            125\n                            \n\n']

# %%
Ratings = []
for i in soup.find_all('td',class_="table-body__cell u-text-right rating"):
    Ratings.append((i.text))
Ratings
# Out:
# ['125',
#  '106',
#  '105',
#  '101',
#  '99',
#  '95',
#  '92',
#  '72',
#  '69',
#  '54',
#  '45',
#  '38',
#  '34',
#  '32',
#  '31',
#  '27',
#  '22',
#  '17',
#  '6']

# %%
print(len(Team_Name),len(points),len(Ratings))
# Out:
# 25 38 19

# %%
df = pd.DataFrame({'Team_Name': Team_Name,'points': points,'Ratings': Ratings})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11620/808452730.py in <module>
# ----> 1 df = pd.DataFrame({'Team_Name': Team_Name,'points': points,'Ratings': Ratings})
#       2 df
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# ...
